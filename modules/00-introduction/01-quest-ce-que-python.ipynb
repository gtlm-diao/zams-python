# %% [markdown]
# <a id="toc"></a>
#
# <div style="background-color:rgb(27, 40, 54); padding: 20px; border-radius: 10px; margin-bottom: 30px;">
#     <h1 style="color: white; font-family: 'Segoe UI', Arial, sans-serif; font-size: 2.8em; text-align: center; margin: 0;">
#         Initiation à la Programmation Python 🐍
#     </h1>
#     <p style="color:rgb(242, 255, 0); font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.2em; text-align: center; margin-top: 10px; font-style: italic;">
#         Module d'introduction au langage Python
#     </p>
# </div>
#
#
# De nos jours, apprendre à coder avec Python est une compétence **très très recherchée** dans beaucoup de métiers et **pas uniquement pour les Informaticiens, les Ingénieurs ou les Scientifiques**.
# ***Tout le monde peut et doit,*** à mon humble avis, ***l'apprendre quelque soit son domaine de travail ou d'étude (les matheux diront quelque soit votre domaine de définition 😉)!***
#
#
# Nous allons dans cette première partie introduire des généralités sur le language Python.
#
#
# <figure style="padding: 1em; text-align: center;">
#     <img src="../../ressources/images/zams_python3.png" width="600" height="400" alt="Logo Python">
#     <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#         <i>Image générée par ChatGPT. Spoiler alert: ChatGPT a été codé avec Python 👀! <a href="https://openclassrooms.com/fr/courses/7150616-apprenez-la-programmation-orientee-objet-avec-python/7197146-comprenez-la-programmation-orientee-objet" target="_blank"></a></i>
#     </figcaption>
# </figure>
#
#
# <div style="background-color:rgb(27, 40, 54); padding: 15px; border-radius: 5px; margin-bottom: 30px;">
#     <h2 style="color:rgb(255, 255, 255); font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.5em; border-bottom: 2px solid #3498DB; padding-bottom: 5px;">
#         Table des matières 📑
#     </h2>
#     <ul style="font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.1em;">
#         <li><a href="#section1" style="color: #3498DB; text-decoration: none;">I. Définition: C'est quoi Python? </a></li>
#         <li><a href="#section2" style="color: #3498DB; text-decoration: none;">II. Histoire de Python</a></li>
#         <li><a href="#section3" style="color: #3498DB; text-decoration: none;">III. Caractéristiques de Python</a></li>
#         <li><a href="#section4" style="color: #3498DB; text-decoration: none;">IV. Popularité & Avantages</a></li>
#         <li><a href="#section5" style="color: #3498DB; text-decoration: none;">V. Domaines d'applications</a></li>
#         <li><a href="#section6" style="color: #3498DB; text-decoration: none;">VI. Ressources complémentaires</a></li>
#     </ul>
# </div>

# %% [markdown]
# <div id="section1"></div>
# <h2 style="color: #3498DB; font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; border-bottom: 2px solid #3498DB; padding-bottom: 5px; margin-top: 40px;">
#     I. Définition: C'est quoi Python?
# </h2>
#
# **Python** est un logiciel ou, tout simplement, pour etre plus juste, un [**langage de programmation**](https://fr.wikipedia.org/wiki/Langage_de_programmation).
# Mais en fait, c'est l'**un des** languages (pour ne pas dire **LE** language) de programmation le plus largement utilisé aujoud'hui (à l'heure ou j'écris cette définition). Les développeurs utilisent Python parce qu'il est **efficace, facile à apprendre**, et peut s'exécuter sur de **nombreuses plateformes** différentes (on verra ses caractériques en détails dans une des sections suivantes).
#
# Python peut être téléchargé librement et **gratuitement**, s'intègre bien avec tous les types de systèmes et accélère le développement.
#
#
# <figure style="padding: 1em; text-align: center;">
#     <img src="https://fastnetmon.com/wp-content/uploads/2016/08/python-logo.png" width="800" height="250" alt="Logo Python">
#     <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#         <i>Logo officiel du langage Python - <a href="https://fastnetmon.com/addons/python-logo/" target="_blank">Source: Python.org</a></i>
#     </figcaption>
# </figure>

# %% [markdown]
# <div id="section2"></div>
#
# <a href="#toc" style="background-color: #E1B12D; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 50px;">Retour en haut</a><a id="toc"></a>
#
# <h2 style="color: #3498DB; font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; border-bottom: 2px solid #3498DB; padding-bottom: 5px; margin-top: 40px;">
#     II. Histoire de Python
# </h2>
#
# **Guido Van Rossum**, un programmeur informatique des **Pays-Bas**, a créé **Python**. Il a commencé en **1989** au [**Centrum Wiskunde & Informatica**](https://fr.wikipedia.org/wiki/Centrum_voor_Wiskunde_en_Informatica) (*CWI*, en francais: « *Centre pour les mathématiques et l'informatique* » aux Pays-Bas.), initialement comme un projet de loisir pour rester occupé pendant la période de **Noël**. Le nom de la langue a été inspiré par l'émission télévisée de la [**BBC Monty Python's Flying Circus**](https://en.wikipedia.org/wiki/Monty_Python%27s_Flying_Circus), car Van Rossum était un grand fan de cette émission.
#
# Voici un bref historique des versions de **Python**:
# - **Guido Van Rossum** a publié la première version du code Python (**version 0.9.0**) en **1991**. Il comprenait déjà de bonnes fonctionnalités telles que certains **types de données** et des **fonctions de gestion des erreurs**.
# - **Python 1.0** est sorti en **1994** avec de nouvelles fonctions permettant de traiter facilement une liste de données, telles que **map**, **filter** et **reduce**.
# - **Python 2.0** a été publié le **16 octobre 2000**, avec de nouvelles fonctions utiles pour les programmeurs, telles que la prise en charge des **caractères Unicode** et une façon plus courte de **boucler dans une liste**.
# - Le **3 décembre 2008**, **Python 3.0** a été publié. Il comprenait des fonctions telles que **l'impression** et une meilleure prise en charge de la **division des nombres** et du **traitement des erreurs**.
#
# <figure style="padding: 1em; text-align: center;">
#     <img src="../../ressources/images/01/histoire_python.png" width="800" height="250" alt="Logo Python">
#     <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#         <i>Histoire de Python - <a href="https://topictrick.medium.com/python-do-you-really-need-it-23fd30c5e3f" target="_blank">Source: Medium</a></i>
#     </figcaption>
# </figure>
#
#
# Cette brève vidéo YouTube explique l'histoire du language Python.
# Elle est facultative. Vous pouvez la visionner ou passer directement à la section suivante.
#
#
# <div style="text-align: center;">
# <iframe width="560" height="315" src="https://www.youtube.com/embed/AqtPg6qVfa8" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
# </div>

# %% [markdown]
# <div id="section3"></div>
#
# <a href="#toc" style="background-color: #E1B12D; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 50px;">Retour en haut</a><a id="toc"></a>
#
# <h2 style="color: #3498DB; font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; border-bottom: 2px solid #3498DB; padding-bottom: 5px; margin-top: 40px;">
#     III. Caractéristiques de <b>Python</b>
# </h2>
#
# <figure style="padding: 1em; text-align: center;">
#     <img src="../../ressources/images/01/caracteristiques.png" width="600" height="400" alt="Logo Python">
#     <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#         <i>Caractéristiques de Python</i>
#     </figcaption>
# </figure>
#
# <p><b>Python</b> est un langage de programmation possédant de multiples caractéristiques et diverses facettes.
# Il est <b>open-source</b>, <b>orienté objet</b>, de <b>haut niveau</b> et à <b>usage général</b> (<i>c-à-d polyvalent</i>). Ces termes peuvent, à première vue, sembler lourds et accablants. Examinons chaque caractéristique séparément pour comprendre ce qu'elle signifie clairement :</p>
#
# <div style="display: flex; align-items: flex-start;">
#   <div style="flex: 1; padding: 1em;">
#     <p>
#       - <b>Open-source</b> 🔓  <br/><br/>
#         Il est <b>gratuit</b> et accessible à tous pour d'autres <b>améliorations</b>, comme l'<b>ajout de fonctionnalités utiles</b>, la <b>correction de bogues</b>, l'<b>ajout de bibliothèques</b> etc...
#     </p>
#   </div>
#   <div style="flex: 1; padding: 1em; text-align: right;">
#     <figure style="padding: 1em; text-align: center;">
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/eb/Open_Source_Initiative.svg/685px-Open_Source_Initiative.svg.png" width="150" height="150" alt="Logo Python">
#         <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#             <i>Logo of the Open Source Initiative - <a href="https://en.m.wikipedia.org/wiki/File:Open_Source_Initiative.svg" target="_blank">Source: Wikipedia</a></i>
#         </figcaption>
#     </figure>
#   </div>
# </div>
#
# <div style="display: flex; align-items: flex-start;">
#   <div style="flex: 1; padding: 1em;">
#     <p>
#       - <b>Orienté objet</b> 🧩  <br/><br/>
#         <b>Python</b> considère tout comme un <b>objet</b>, mais il prend également en charge d'autres types de programmation tels que la <b>programmation structurée</b> et <b>fonctionnelle</b>.
#         Il est basé non pas sur des fonctions mais sur des <b>objets avec des attributs et des méthodes définis</b> (<i>Nous verrons par la suite la notion d'orienté objet en profondeur</i>).
#     </p>
#   </div>
#   <div style="flex: 1; padding: 1em; text-align: right;">
#     <figure style="padding: 1em; text-align: center;">
#         <img src="../../ressources/images/01/oriente_objet.png" width="600 " height="200" alt="Logo Python">
#         <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#             <i>Voici deux beaux gâteaux ! - <a href="https://openclassrooms.com/fr/courses/7150616-apprenez-la-programmation-orientee-objet-avec-python/7197146-comprenez-la-programmation-orientee-objet" target="_blank">Source: OpenClassrooms</a></i>
#         </figcaption>
#     </figure>
#   </div>
# </div>
#
# <div style="display: flex; align-items: flex-start;">
#   <div style="flex: 1; padding: 1em;">
#     <p>
#       - <b>Interprété</b> 📝  <br/><br/>
#         <b>Python</b> est un langage <b>interprété</b>, ce qui signifie qu'il <b>exécute directement le code ligne par ligne</b>. S'il y a des <b>erreurs</b> dans le code du programme, celui-ci s'arrête de fonctionner. Les programmeurs peuvent donc <b>trouver rapidement les erreurs</b> dans le code.
#     </p>
#   </div>
#   <div style="flex: 1; padding: 1em; text-align: right;">
#     <figure style="padding: 1em; text-align: center;">
#         <img src="https://codeur-pro.fr/wp-content/uploads/2021/03/7-types_de_langages.png" width="700" height="200" alt="Logo Python">
#         <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#             <i>Logo of the Open Source Initiative - <a href="https://codeur-pro.fr/comment-creer-un-programme/" target="_blank">Source: codeur-pro.fr/</a></i>
#         </figcaption>
#     </figure>
#   </div>
# </div>
#
# <div style="display: flex; align-items: flex-start;">
#   <div style="flex: 1; padding: 1em;">
#     <p>
#       - <b>Haut niveau</b> ⏫  <br/><br/>
#         Il est <b>convivial</b> et est plus proche des <b>langues humaines</b> (<i>facilement compréhensible par l'Homme</i>) . En revanche, certains langages comme l'<b>Assembleur</b> sont dits de <b>bas niveau</b> car étant proches de la "<b>langue maternelle</b>" d'un ordinateur (<b>le binaire</b>), ce qui les rend plus <b>difficiles à comprendre</b> pour nous. Par conséquent, les programmeurs ne doivent pas se préoccuper de ses <b>fonctionnalités sous-jacentes</b> telles que l'<b>architecture</b> et la <b>gestion de la mémoire</b>.
#     </p>
#   </div>
#   <div style="flex: 1; padding: 1em; text-align: right;">
#     <figure style="padding: 1em; text-align: center;">
#         <img src="../../ressources/images/01/haut_niveau.png" width="600 " height="200" alt="Logo Python">
#         <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#             <i>High Level & Low Level Languages - <a href="https://www.helpteaching.com/lessons/1285/high-level-low-level-languages" target="_blank">Source: HelpTeaching.com</a></i>
#         </figcaption>
#     </figure>
#   </div>
# </div>
#
# <div style="display: flex; align-items: flex-start;">
#   <div style="flex: 1; padding: 1em;">
#     <p>
#       - <b>Polyvalent</b> 🔄  <br/><br/>
#         Il peut être utilisé pour <b>créer n'importe quel type de programme</b>. Il a une variété d'<b>applications</b> allant du <b>Développement Web</b> à l'<b>Intelligence Artificielle</b> (<i>on verra ses domaines d'applications plus bas</i>).
#     </p>
#   </div>
#   <div style="flex: 1; padding: 1em; text-align: right;">
#     <figure style="padding: 1em; text-align: center;">
#         <img src="../../ressources/images/01/polyvalent.png" width="600 " height="200" alt="Logo Python">
#         <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#             <i>Python est le leader incontesté en matière de science des données, d’automatisation et d’intelligence artificielle. - <a href="https://medium.com/@talktorahul.b/why-python-is-still-unbeatable-a-versatile-language-for-the-modern-era-f574d476e83e" target="_blank">Source: Medium</a></i>
#         </figcaption>
#     </figure>
#   </div>
# </div>
#
# <div style="display: flex; align-items: flex-start;">
#   <div style="flex: 1; padding: 1em;">
#     <p>
#       - <b>À typage dynamique</b>  <br/><br/>
#         Les programmeurs ne doivent pas déclarer les <b>types de variables</b> lors de l'écriture du code, car <b>Python</b> les détermine au moment de l'<b>exécution</b>. Grâce à cela, vous pouvez <b>écrire des programmes Python plus rapidement</b>.
#     </p>
#   </div>
#   <div style="flex: 1; padding: 1em; text-align: right;">
#     <figure style="padding: 1em; text-align: center;">
#         <img src="https://miro.medium.com/v2/resize:fit:1200/1*BddwVWW6hFU0miT9DCbUWQ.png" width="600" height="200" alt="Logo Python">
#         <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#             <i>Classification des languages en fonction du typage - <a href="https://medium.com/android-news/magic-lies-here-statically-typed-vs-dynamically-typed-languages-d151c7f95e2b" target="_blank">Source: Medium</a></i>
#         </figcaption>
#     </figure>
#   </div>
# </div>

# %% [markdown]
# <div id="section4"></div>
#
# <a href="#toc" style="background-color: #E1B12D; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 50px;">Retour en haut</a><a id="toc"></a>
#
# <h2 style="color: #3498DB; font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; border-bottom: 2px solid #3498DB; padding-bottom: 5px; margin-top: 40px;">
#     IV. Popularité & Avantages
# </h2>
#
# **Python** est l'un des langages de programmation **les plus populaires au monde** utilisé par des grandes organisations comme **Microsoft**, la **NASA**, **Google** ou encore **Meta**. C'est l'un des langages de programmation **les plus puissants** et paradoxalement, l'un des **plus simples à apprendre**.  <br/>
#
# Les développeurs peuvent facilement **lire** et **comprendre** un programme Python, car il possède une **syntaxe de base**, semblable à celle de l’**anglais**.
#
# <figure style="padding: 1em; text-align: center;">
#     <img src="https://f.hellowork.com/blogdumoderateur/2025/01/classement-langages-programmation-janvier-2025-tiobe.jpg" width="600" height="400" alt="Classement des langages de programmation">
#     <figcaption style="font-size: 0.9em; color:rgb(71, 129, 255); margin-top: 0.5em;">
#         <i>TIOBE a élu <b>Python</b> langage de programmation de l'année 2024, durant laquelle il a gagné près de <b>10 points de popularité</b>. <a href="https://www.tiobe.com/tiobe-index/" target="_blank">Source: TIOBE Software</a></i>
#     </figcaption>
# </figure>
#
# D'autres **avantages de Python** sont entre autre :
# - Python rend les développeurs **plus productifs**, car ils peuvent écrire un programme Python en utilisant **moins de lignes de code** par rapport à de nombreux autres langages.
# - Python dispose d'une **vaste bibliothèque standard** qui contient des **codes réutilisables** pour presque toutes les tâches. Par conséquent, les développeurs ne doivent pas écrire le code à partir de zéro.
# - Les développeurs peuvent facilement utiliser Python avec d'autres **langages de programmation populaires** comme **Java**, **C** et **C++**.
# - La **communauté Python active** comprend des **millions de développeurs solidaires** dans le monde entier. Si vous rencontrez un problème, vous pouvez obtenir un **soutien rapide** de la part de la communauté.
# - De nombreuses **ressources utiles** sont disponibles sur Internet si vous souhaitez apprendre Python. Par exemple, vous pouvez facilement trouver des **vidéos**, des **didacticiels**, de la **documentation** et des **guides pour les développeurs**.
# - Python est **portable** sur différents **systèmes d'exploitation** informatiques tels que **Windows**, **macOS**, **Linux** et **Unix**.

# %% [markdown]
# <div id="section5"></div>
#
# <a href="#toc" style="background-color: #E1B12D; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 50px;">Retour en haut</a><a id="toc"></a>
#
# <h2 style="color: #3498DB; font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; border-bottom: 2px solid #3498DB; padding-bottom: 5px; margin-top: 40px;">
#     V. Domaines d'applications
# </h2>
#
# <b>Grâce à ses nombreuses bibliothèques</b>, il est utilisé entre autres pour:
# <div style="display: flex; align-items: flex-start;">
#   <div style="flex: 1; padding: 1em;">
#     <p>
#       - <b>Le Calcul Scientifique et Numérique 🧪 </b>  <br/><br/>
#         L'écosystème Python offre de nombreux outils et bibliothèques qui aident les <b>scientifiques</b> et les <b>chercheurs</b>. Par exemple <i>SciPy</i> et <i>Pandas</i> sont des bibliothèques pour les <b>mathématiques</b>, les <b>sciences</b>, <b>l'ingénierie</b>, <b>l'analyse</b> et la <b>modélisation des données</b>.
#     </p>
#   </div>
#   <div style="flex: 1; padding: 1em; text-align: right;">
#     <figure style="padding: 1em; text-align: center;">
#         <img src="https://miro.medium.com/v2/resize:fit:1100/format:webp/0*h-yuUdS04PpgH3oP.jpg" width="600 " height="200" alt="Python pour le calcul scientifique">
#         <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#             <i>Bibliothèques Python utilisées dans le calcul scientifique et l'analyse de données - <a href="https://medium.com/towards-data-science/data-science-with-python-intro-to-data-visualization-and-matplotlib-5f799b7c6d82" target="_blank">Source: Medium/Towards Data Science</a></i>
#         </figcaption>
#     </figure>
#   </div>
# </div>
#
# <div style="display: flex; align-items: flex-start;">
#   <div style="flex: 1; padding: 1em;">
#     <p>
#       - <b>Le Développement Web 🌐 </b>  <br/><br/>
#         Certes <b>HTML</b> et <b>JavaScript</b> sont les principaux langages utilisés pour construire le <b>front-end</b> d'une application web, mais des <b>frameworks</b> basés sur Python tels que <i>Django</i>, <i>Pyramid</i>, <i>Web2Py</i> et <i>Flask</i> sont utilisés pour gérer le <b>back-end</b> et les <b>fonctionnalités côté serveur</b> des sites. Des plateformes géantes comme <b>Google</b> et <b>YouTube</b> dépendent largement de Python pour leur <b>infrastructure</b>.
#     </p>
#   </div>
#   <div style="flex: 1; padding: 1em; text-align: right;">
#     <figure style="padding: 1em; text-align: center;">
#         <img src="https://miro.medium.com/v2/resize:fit:1100/format:webp/0*74y4AW2sirTyKYq9.jpg" width="600 " height="200" alt="Python pour le développement web">
#         <figcaption style="font-size: 0.9em; color:  #3498db; margin-top: 0.5em;">
#             <i>Frameworks Python populaires pour le développement web (Django, Flask, FastAPI) - <a href="https://www.djangoproject.com/" target="_blank">Source: Django Project</a></i>
#         </figcaption>
#     </figure>
#   </div>
# </div>
#
# <div style="display: flex; align-items: flex-start;">
#   <div style="flex: 1; padding: 1em;">
#     <p>
#       - <b>Le Data Science et l'Intelligence Artificielle 🧠 </b>  <br/><br/>
#         L'<b>étendue</b> et la <b>puissance</b> de Python, ainsi que sa <b>stabilité</b> et sa <b>sécurité</b>, en font le langage par excellence pour faire fonctionner les systèmes d'<b>Intelligence Artificielle</b> et de <b>Machine Learning</b>. Des bibliothèques importantes comme <i>Scikit-Learn</i>, <i>TensorFlow</i>, <i>PyTorch</i>, <i>Keras</i> sont utilisés pour construire divers <b>modèles de Machine Learning</b> et de <b>réseaux de neurones artificiels</b> de pointe (<b>Deep Learning</b>).
#     </p>
#   </div>
#   <div style="flex: 1; padding: 1em; text-align: right;">
#     <figure style="padding: 1em; text-align: center;">
#         <img src="https://miro.medium.com/v2/resize:fit:1100/format:webp/0*WQrQiprHvkCSRi-U.png" width="600 " height="200" alt="Python pour l'IA et la Data">
#         <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#             <i>Écosystème Python pour l'intelligence artificielle et l'apprentissage automatique - <a href="https://www.tensorflow.org/" target="_blank">Source: TensorFlow</a></i>
#         </figcaption>
#     </figure>
#   </div>
# </div>
#
# <div style="display: flex; align-items: flex-start;">
#   <div style="flex: 1; padding: 1em;">
#     <p>
#       - <b>Le Développement de Jeux Vidéos 🎮 </b>  <br/><br/>
#         Python a été utilisé pour développer des <b>jeux populaires</b>, tels que <i>Sims 4</i>, <i>World of Tanks</i>, <i>Eve Online</i>, <i>Mount & Blade</i> pour n'en citer que quelques-uns. Les <b>bibliothèques de développement de jeux 2D et 3D</b> de Python sont <i>PyGame</i>, <i>Pycap</i>, <i>Construct</i>, <i>PySoy</i> et <i>PyOpenGL</i>.
#     </p>
#   </div>
#   <div style="flex: 1; padding: 1em; text-align: right;">
#     <figure style="padding: 1em; text-align: center;">
#         <img src="https://www.lemondedupc.fr/assets/uploads/8b4042d1b3525dd887fc75bdc308ba68.png" width="600 " height="200" alt="Python pour les jeux vidéo">
#         <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#             <i>Pygame est une bibliothèque populaire pour le développement de jeux en Python - <a href="https://www.lemondedupc.fr/article/71-pygame-1-9-6-un-module-python-utilise-pour-vos-creation" target="_blank">Source: lemondedupc.fr</a></i>
#         </figcaption>
#     </figure>
#   </div>
# </div>
#
# Comme je l'ai sus-mentionné c'est un langage <b>polyvalent</b> et bien sûr il y a d'autres <b>utilités</b> et <b>applications</b> comme:
#
# <div style="display: flex; align-items: flex-start;">
#   <div style="flex: 1; padding: 1em;">
#     <p>
#         - <b>La robotique 🤖</b> <br/>
#         - <b>La blockchain 🔗</b> <br/>
#         - <b>La cybersécurité 🔒</b> <br/>
#         - <b>L'automatisation des tâches ⚙️</b> <br/>
#         - <b>Les tests 🧪</b> <br/>
#         - <b>L'écriture de scripts système 💻</b> <br/>
#         - <b>La programmation de systèmes d'exploitation (OS) 🖥️</b> <br/>
#         - <b>Les interfaces graphiques (GUI) 🖌️</b> <br/>
#         - <b>Et bien plus encore!</b>
#     </p>
#   </div>
#   <div style="flex: 1; padding: 1em; text-align: right;">
#     <figure style="padding: 1em; text-align: center;">
#         <img src="../../ressources/images/01/applications.png" width="600 " height="200" alt="Logo Python">
#         <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#             <i>Python est le leader incontesté en matière de science des données, d’automatisation et d’intelligence artificielle. - <a href="https://medium.com/@talktorahul.b/why-python-is-still-unbeatable-a-versatile-language-for-the-modern-era-f574d476e83e" target="_blank">Source: Medium</a></i>
#         </figcaption>
#     </figure>
#   </div>
# </div>

# %% [markdown]
# <div id="section6"></div>
#
# <a href="#toc" style="background-color: #E1B12D; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 50px;">Retour en haut</a><a id="toc"></a>
#
# <h2 style="color: #3498DB; font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; border-bottom: 2px solid #3498DB; padding-bottom: 5px; margin-top: 40px;">
#     VI. 📚 Ressources complémentaires
# </h2>
#
# <div style="display: flex; align-items: flex-start;">
#   <div style="flex: 1; padding: 1em;">
#     <p>
#         - [1 📖] <a href="https://codeur-pro.fr/comment-creer-un-programme/" target="_blank">Article de Blog - Comment créer un programme?</a> - une bonne illustration de la différence entre language compilé et interprété.<br/>
#         - [2 📖] <a href="https://laconsole.dev/blog/differences-langage-compile-interprete" target="_blank">Article de Blog - Différences entre Langage Interprété et Compilé</a>
#     </p>
#     <!-- Vous pouvez continuer votre texte ici -->
#   </div>
#   <div style="flex: 1; padding: 1em; text-align: right;">
#     <figure style="margin: 0;">
#       <img src="../../ressources/images/python-meme-4.png" width="400" height="600" alt="Logo Python">
#       <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#         <i>Image générée par ChatGPT.</i>
#       </figcaption>
#     </figure>
#   </div>
# </div>
