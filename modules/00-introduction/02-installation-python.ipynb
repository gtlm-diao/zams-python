# %% [markdown]
# <a id="toc"></a>
#
# <div style="background-color:rgb(27, 40, 54); padding: 20px; border-radius: 10px; margin-bottom: 30px;">
#     <h1 style="color: white; font-family: 'Segoe UI', Arial, sans-serif; font-size: 2.8em; text-align: center; margin: 0;">
#         Installation de Python 🐍
#     </h1>
#     <p style="color:rgb(242, 255, 0); font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.2em; text-align: center; margin-top: 10px; font-style: italic;">
#         Module d'introduction au langage Python
#     </p>
# </div>
#
#
#
#
#
# <div style="background-color:rgb(27, 40, 54); padding: 15px; border-radius: 5px; margin-bottom: 30px;">
#     <h2 style="color:rgb(255, 255, 255); font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.5em; border-bottom: 2px solid #3498DB; padding-bottom: 5px;">
#         Table des matières 📑
#     </h2>
#     <ul style="font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.1em;">
#         <li><a href="#section1" style="color: #3498DB; text-decoration: none;">I. IDEs Python </a></li>
#         <li><a href="#section2" style="color: #3498DB; text-decoration: none;">II. Installation de Python</a></li>
#         <li><a href="#section3" style="color: #3498DB; text-decoration: none;">III. Environnements virtuels</a></li>
#         <li><a href="#section4" style="color: #3498DB; text-decoration: none;">IV. Packages Managers</a></li>
#     </ul>
# </div>

# %% [markdown]
# <div id="section1"></div>
#
# <h2 style="color: #3498DB; font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; border-bottom: 2px solid #3498DB; padding-bottom: 5px; margin-top: 40px;">
#     I. IDEs Python 🖥️
# </h2>
#
# Comme vous le savez peut-être déjà, vous pouvez taper et travailler du code Python dans à peu près **n'importe quel éditeur de texte**.
# Toutefois, les éditeurs de texte *« bruts »* ne disposent d’aucune fonctionnalité intégrée spécifiquement conçue pour aider à l’écriture de code, ce qui **n'est pas un flux de travail très efficace**.
#
# En résumé, les **IDEs** et les **éditeurs de code** sont des outils logiciels que les programmeurs utilisent pour surmonter ce problème.
# Ces outils peuvent **grandement améliorer** la productivité, l’efficacité et le confort lorsqu’on travaille avec **Python** ou tout autre langage.
#
#
# <h3 style="color:rgb(242, 255, 0); font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; padding-bottom: 5px; margin-top: 40px;">
#     1. Qu’est-ce qu’un IDE ?
# </h3>
#
# **IDE** signifie tout simplement *Integrated Development Environment* (*Environnement de Développement Intégré*): un type de logiciel qui **combine de nombreux outils courants** de développement dans une seule interface conviviale.
#
# En plus des fonctionnalités de base d’un éditeur de code, un IDE propose généralement :
# - **Auto-complétion intelligente** du code
# - **Débogueur intégré**
# - **Coloration syntaxique** pour une meilleure lisibilité
# - **Mise en forme automatique** (indentation, fermetures de parenthèses, etc.)
#
# *Exemple :*
#
# - **Sans coloration syntaxique :**
# <figure style="padding: 1em; text-align: center;">
#     <img src="" width="200" alt="Logo PyCharm">
#     <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#         <i>Extrait de code Python brut  <a href="" target="_blank"></a></i>
#     </figcaption>
# </figure>
#
# - **Avec coloration syntaxique :**
#
# <figure style="padding: 1em; text-align: center;">
#     <img src="" width="200" alt="Logo PyCharm">
#     <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#         <i>Extrait de code Python coloré : commentaires gris, fonction turquoise, arguments orange, chaînes de caractères vertes  <a href="" target="_blank"></a></i>
#     </figcaption>
# </figure>
#
# Vous pouvez bien constater que cela **améliore considérablement** la clarté et la compréhension du code !
#
#
# <h3 style="color:rgb(242, 255, 0); font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; padding-bottom: 5px; margin-top: 40px;">
#     2. Qu’est-ce qu’un éditeur de code ?
# </h3>
#
# Un **éditeur de code** est un outil *léger*, conçu spécifiquement pour **écrire et modifier** du code.
# Il ressemble beaucoup à un éditeur de texte classique, mais propose en plus :
# - **Coloration syntaxique**
# - **Mise en forme automatique**
# - **Support de multiples langages** via extensions
#
# Un éditeur de code peut fonctionner seul, ou être **intégré dans un IDE** plus complet.
#
#
# <h3 style="color:rgb(242, 255, 0); font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; padding-bottom: 5px; margin-top: 40px;">
#     3. IDE vs. Éditeur de code : lequel choisir ?
# </h3>
#
# | Critères              | IDE 🖥️                                    | Éditeur de code ✏️                            |
# |:----------------------|:----------------------------------------|:---------------------------------------------|
# | Fonctionnalités       | Très complet (écriture, exécution, debug) ✅ | Principalement pour écrire du code |
# | Performance           | Plus lourd ⚠️                            | Très léger ✅                                |
# | Flexibilité           | Moins personnalisable ⚠️                 | Très extensible via plugins ✅               |
# | Idéal pour            | Projets complets / applications complexes ✅ | Scripts rapides / développement léger ✅ |
#
#
# <h3 style="color:rgb(242, 255, 0); font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; padding-bottom: 5px; margin-top: 40px;">
#     4. Exemples d'outils populaires (mes préférés disons)
# </h3>
#
# ### PyCharm (JetBrains)
#
# PyCharm est un **IDE Python** développé par **JetBrains**, largement utilisé par les professionnels.
# Deux éditions sont disponibles :
#
# - **Community** *(gratuite)* :
#   Coloration syntaxique, auto-complétion intelligente, détection d’erreurs à la volée, corrections rapides, exécution et débogage.
# - **Professional** *(payante)* :
#   Ajoute la gestion de bases de données et le support de frameworks web Python (Django, Flask, etc.).
#
# <figure style="padding: 1em; text-align: center;">
#     <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/5/5d/JetBrains_PyCharm_Product_Logo.svg/640px-JetBrains_PyCharm_Product_Logo.svg.png" width="200" alt="Logo PyCharm">
#     <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#         <i>Logo PyCharm – <a href="https://commons.wikimedia.org/wiki/File:JetBrains_PyCharm_Product_Logo.svg" target="_blank">Wikimedia Commons</a></i>
#     </figcaption>
# </figure>
#
# **Points forts :**
# - ✅ **Auto-complétion très intelligente**, refactoring avancé et inspection de code en temps réel.
# - ✅ **Débogueur graphique** performant.
# - ✅ **Gestion native des environnements** virtuels (venv, Conda).
# - ✅ **Support Jupyter/Anaconda** intégré (Professional).
#
# **Limites :**
# - ⚠️ **Chargement parfois lent** sur de très gros projets.
# - ⚠️ **Consommation mémoire élevée**.
# - ⚠️ Certaines fonctionnalités (bases de données, frameworks web) **réservées à la version payante**.
#
#
# ### Visual Studio Code (Microsoft)
#
# **Visual Studio Code (VS Code)** est un **éditeur de code** *gratuit et open-source*, développé par **Microsoft**.
#
# <figure style="padding: 1em; text-align: center;">
#     <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Visual_Studio_Code_1.35_icon.svg/1200px-Visual_Studio_Code_1.35_icon.svg.png" width="150" alt="Logo VS Code">
#     <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#         <i>Logo Visual Studio Code – <a href="https://commons.wikimedia.org/wiki/File:Visual_Studio_Code_1.35_icon.svg" target="_blank">Wikimedia Commons</a></i>
#     </figcaption>
# </figure>
#
# **Points forts :**
# - ✅ **Très léger**, rapide au démarrage.
# - ✅ **Terminal intégré** et **intégration Git native**.
# - ✅ **Énorme écosystème d’extensions** : Python, Pylance, Jupyter, linters, beautifiers, etc.
# - ✅ **Multiplateforme** : Windows, macOS, Linux.
#
# **Limites :**
# - ⚠️ **Configuration initiale** (extensions, Python interpreter) peut être un peu technique.
# - ⚠️ Peut nécessiter **plusieurs plugins** pour une expérience optimale.
#
#
# ### Anaconda / Jupyter Notebook
#
# **Jupyter Notebook** est un environnement de développement **interactif** beaucoup plus récent, souvent utilisé pour :
# - la **Data Science**
# - le **Machine Learning**
# - le **Recherche scientifique**
#
# <figure style="padding: 1em; text-align: center;">
#     <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/38/Jupyter_logo.svg/414px-Jupyter_logo.svg.png" width="150" alt="Logo Jupyter">
#     <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#         <i>Logo Jupyter – <a href="https://commons.wikimedia.org/wiki/File:Jupyter_logo.svg" target="_blank">Wikimedia Commons</a></i>
#     </figcaption>
# </figure>
#
# **Points forts :**
# - ✅ **Interface web interactive** : code, notes, graphiques côte-à-côte.
# - ✅ **Exécution du code par cellule** pour une flexibilité maximale.
# - ✅ **Idéal pour la visualisation et le partage** de notebooks.
# - ✅ **Support multi-langages** via kernels (ex : IPython pour Python).
#
# **Limites :**
# - ⚠️ **Moins adapté aux projets complexes** ou aux applications nécessitant une architecture stricte.
# - ⚠️ **Gestion de projet et debug** plus limités qu'avec un IDE complet.
#
# ### Pour résumer.
#
# | Outil                | Points forts | Limites principales |
# |:---------------------|:--------------|:--------------------|
# | **PyCharm**           | IDE complet, outils avancés pour projets sérieux | Lourd, certaines fonctionnalités payantes |
# | **VS Code**           | Léger, hautement personnalisable | Nécessite plusieurs extensions |
# | **Jupyter Notebook**  | Parfait pour la Data Science | Moins adapté aux projets complexes |

# %% [markdown]
# <div id="section2"></div>
# <a href="#toc" style="background-color: #E1B12D; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 50px;">Retour en haut</a><a id="toc"></a>
#
# <h2 style="color: #3498DB; font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; border-bottom: 2px solid #3498DB; padding-bottom: 5px; margin-top: 40px;">
#     II. Installation de Python
# </h2>
#
# <figure style="padding: 1em; text-align: center;">
#     <img src="../../ressources/images/02/python-source.png" width="800" height="500" alt="Logo PyCharm">
#     <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#         <i>Python website  <a href="" target="_blank"></a></i>
#     </figcaption>
# </figure>
#
#
# <p style="font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.1em; line-height: 1.6em;">
#     Allons chercher Python directement à la source : <a href="https://www.python.org/downloads/" target="_blank" style="color: #3498DB; text-decoration: none;"><strong>python.org/downloads</strong></a>.
#     <br/><br/>
#     <strong>Étapes à suivre</strong> :
# </p>
#
#
# <ol style="font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.1em; margin-left: 1.5em; line-height: 1.6em;">
#     <li><strong>Télécharger l’installeur</strong> pour votre OS (Windows, macOS, Linux).</li>
#     <li><strong>Exécuter l’installeur</strong> :
#         <ul style="margin-left: 1em;">
#             <li>✔️ Cochez « Add Python to PATH » sur Windows.</li>
#             <li>✔️ Sur macOS, glissez‑déposez dans Applications ou utilisez Homebrew (<code>brew install python</code>).</li>
#             <li>✔️ Sous Linux, privilégiez le gestionnaire de paquets (<code>sudo apt install python3</code>).</li>
#         </ul>
#     </li>
#     <li><strong>Vérifier l’installation</strong> :
#         <pre style="background:rgb(105, 105, 105); padding: 10px; border-radius: 5px; overflow-x: auto; font-family: Consolas, monospace; font-size: 0.95em;">
# $ python --version
# Python 3.x.x
#         </pre>
#     </li>
# </ol>

# %% [markdown]
# <div id="section3"></div>
# <a href="#toc" style="background-color: #E1B12D; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 50px;">Retour en haut</a><a id="toc"></a>
#
# <h2 style="color: #3498DB; font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; border-bottom: 2px solid #3498DB; padding-bottom: 5px; margin-top: 40px;">
#     III. Environnements virtuels 🐍
# </h2>
# <p style="font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.1em; line-height: 1.6em;">
#     Pourquoi un environnement virtuel ? Pour isoler les dépendances de chaque projet et éviter les conflits de versions.
#     <br/><br/>
#     <strong>Créer et activer un venv</strong> (module standard) :
# </p>
# <pre style="background:rgb(105, 105, 105); padding: 10px; border-radius: 5px; overflow-x: auto; font-family: Consolas, monospace; font-size: 0.95em;">
# $ python -m venv mon_env
# $ # Windows
# $ mon_env\Scripts\activate
# $ # macOS / Linux
# $ source mon_env/bin/activate
# </pre>
# <p style="font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.1em; line-height: 1.6em;">
#     Pour quitter l’environnement :
#     <code>deactivate</code>
#     <br/><br/>
#     <strong>Alternative Conda</strong> (Anaconda/Miniconda) :
#     <pre style="background: rgb(105, 105, 105); padding: 10px; border-radius: 5px; overflow-x: auto; font-family: Consolas, monospace; font-size: 0.95em;">
# $ conda create -n mon_env_conda python=3.x
# $ conda activate mon_env_conda
# $ conda deactivate
#     </pre>
# </p>

# %% [markdown]
# <div id="section4"></div>
# <a href="#toc" style="background-color: #E1B12D; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 50px;">Retour en haut</a><a id="toc"></a>
#
# <h2 style="color: #3498DB; font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; border-bottom: 2px solid #3498DB; padding-bottom: 5px; margin-top: 40px;">
#     IV. Package Managers 📦
# </h2>
# <p style="font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.1em; line-height: 1.6em;">
#     Gérer vos bibliothèques, c’est comme ranger vos outils : on veut un système clair et fiable.
#     <br/><br/>
#     <strong>pip</strong> (standard) :
# </p>
# <ul style="font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.1em; margin-left: 1.5em; line-height: 1.6em;">
#     <li>Installer : <code>pip install nom_du_package</code></li>
#     <li>Mettre à jour : <code>pip install --upgrade nom_du_package</code></li>
#     <li>Désinstaller : <code>pip uninstall nom_du_package</code></li>
#     <li>Lister : <code>pip list</code></li>
#     <li>Exporter : <code>pip freeze &gt; requirements.txt</code></li>
# </ul>
# <p style="font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.1em; line-height: 1.6em;">
#     <strong>Poetry</strong> (gestion avancée) :
#     <ul style="margin-left: 1.5em;">
#         <li>✔️ Fichier <code>pyproject.toml</code> pour config unifiée.</li>
#         <li>✔️ Isolation et publication simplifiée.</li>
#     </ul>
#     <strong>Conda</strong> (via Anaconda) :
#     <ul style="margin-left: 1.5em;">
#         <li>✔️ Environnements + packages scientifiques pré‑compilés.</li>
#         <li>⚠️ Lourd à installer si on n’a pas besoin de tout l’écosystème.</li>
#     </ul>
# </p>

# %% [markdown]
# <div id="section6"></div>
#
# <a href="#toc" style="background-color: #E1B12D; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 50px;">Retour en haut</a><a id="toc"></a>
#
# <h2 style="color: #3498DB; font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; border-bottom: 2px solid #3498DB; padding-bottom: 5px; margin-top: 40px;">
#     VI. 📚 Ressources complémentaires
# </h2>
#
# <div style="display: flex; align-items: flex-start;">
#   <div style="flex: 1; padding: 1em;">
#     <p>
#     </p>
#   </div>
# </div>
