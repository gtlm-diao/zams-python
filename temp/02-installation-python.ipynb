# %% [markdown]
# <a id="toc"></a>
#
# <div style="background-color:rgb(27, 40, 54); padding: 20px; border-radius: 10px; margin-bottom: 30px;">
#     <h1 style="color: white; font-family: 'Segoe UI', Arial, sans-serif; font-size: 2.8em; text-align: center; margin: 0;">
#         Installation de Python 🐍
#     </h1>
#     <p style="color:rgb(242, 255, 0); font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.2em; text-align: center; margin-top: 10px; font-style: italic;">
#         Module d'introduction au langage Python
#     </p>
# </div>
#
#
#
#
#
# <div style="background-color:rgb(27, 40, 54); padding: 15px; border-radius: 5px; margin-bottom: 30px;">
#     <h2 style="color:rgb(255, 255, 255); font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.5em; border-bottom: 2px solid #3498DB; padding-bottom: 5px;">
#         Table des matières 📑
#     </h2>
#     <ul style="font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.1em;">
#         <li><a href="#section1" style="color: #3498DB; text-decoration: none;">I. IDEs Python </a></li>
#         <li><a href="#section2" style="color: #3498DB; text-decoration: none;">II. Installation de Python</a></li>
#         <li><a href="#section3" style="color: #3498DB; text-decoration: none;">III. Environnements virtuels</a></li>
#         <li><a href="#section4" style="color: #3498DB; text-decoration: none;">IV. Packages Managers</a></li>
#     </ul>
# </div>

# %% [markdown]
# <div id="section1"></div>
# <h2 style="color: #3498DB; font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; border-bottom: 2px solid #3498DB; padding-bottom: 5px; margin-top: 40px;">
#     I. IDEs Python 🖥️
# </h2>
#
# Comme vous le savez peut-être déjà, vous pouvez taper et travailler du code Python dans à peu près n’importe quel éditeur de texte. Toutefois, les éditeurs de texte “bruts” ne disposent d’aucune fonctionnalité intégrée spécifiquement conçue pour aider à l’écriture de code, ce qui n’est pas un flux de travail très efficace.
#
# En résumé, les IDE et les éditeurs de code sont des outils logiciels que les programmeurs utilisent pour surmonter ce problème. Ces outils peuvent grandement améliorer la productivité, l’efficacité et le confort lorsqu’on travaille avec Python ou tout autre langage d'ailleurs.
#
#
# <h3 style="color:rgb(183, 232, 7); font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; border-bottom: 2px solid #3498DB; padding-bottom: 5px; margin-top: 40px;">
#     1. Qu’est-ce qu’un IDE ?
# </h3>
# IDE signifie « Integrated Development Environment » (environnement de développement intégré) : un type de logiciel qui combine de nombreux outils courants de développement dans une seule interface conviviale. En plus des fonctionnalités de base d’un éditeur de code, un IDE inclut généralement des fonctionnalités supplémentaires telles que l’auto-complétion de code et le débogage.
#
# La coloration syntaxique, par exemple, est une fonctionnalité des IDE et des éditeurs de code qui aide le programmeur en fournissant des repères visuels (par exemple, le code est mis en couleur selon sa nature). L’éditeur de code connaît la syntaxe du langage que vous utilisez et peut donc en clarifier la structure.
#
#
# Voici le code d’une fonction Python qui vérifie si un nombre est positif, négatif ou nul sans coloration syntaxique :
#
# [Extrait de code Python sans coloration syntaxique]
#
# Et voici la même fonction avec coloration syntaxique : remarquez que, par exemple, le commentaire est en gris, le nom de la fonction en turquoise, les arguments en orange et les chaînes de caractères en vert. Cela rend le code beaucoup plus facile à lire :
#
# [Extrait de code Python avec coloration syntaxique]
#
#
# Puisque l’éditeur connaît la syntaxe du langage, il peut aussi aider à la mise en forme du code : il peut ajouter automatiquement l’indentation ou les parenthèses de fermeture.
#
#
# <h3 style="color:rgb(183, 232, 7); font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; border-bottom: 2px solid #3498DB; padding-bottom: 5px; margin-top: 40px;">
#     2. Qu’est-ce qu’un éditeur de code ?
# </h3>
# Les éditeurs de code sont des outils légers pour, vous l’aurez deviné, écrire et modifier du code. Ils ressemblent beaucoup à un éditeur de texte classique, mais avec quelques fonctionnalités supplémentaires qui aident énormément à la rédaction de code. Un bon éditeur de code inclura au minimum la coloration syntaxique et la mise en forme automatique du code.
#
#
# <h3 style="color:rgb(183, 232, 7); font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; border-bottom: 2px solid #3498DB; padding-bottom: 5px; margin-top: 40px;">
#     3. IDE vs. éditeur de code : lequel choisir ?
# </h3>
# Un IDE est un outil complet que vous pouvez utiliser pour l’ensemble du cycle de développement logiciel. Un IDE intègre dans une seule application la rédaction, la compilation (ou l’interprétation), l’exécution et le débogage du code, de sorte que vous n’avez que rarement besoin d’autres programmes. Les IDE proposent également des fonctionnalités comme la coloration syntaxique, l’auto-complétion et bien d’autres pour optimiser votre flux de travail.
#
# Un éditeur de code est en général une application dédiée à l’édition de code source : pour compiler, interpréter ou exécuter le code, vous aurez besoin d’un autre outil. Cela confère toutefois à l’éditeur de code certains avantages : il est souvent plus léger et personnalisable via des extensions ou plugins. Un éditeur de code peut fonctionner seul ou être intégré à un IDE.
#
#
#
#
#
# <ul style="font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.1em; margin-left: 1.5em;">
#     <li><strong>PyCharm</strong> (JetBrains) :
#     PyCharm est un IDE Python développé par JetBrains, très utilisé par les professionnels. Il existe en deux éditions :
#
#     Community (gratuite, licence Apache) : coloration syntaxique, auto-complétion intelligente, détection d’erreurs à la volée, corrections rapides, exécution et débogage de code.
#
#     Professional (payante) : ajoute la gestion de bases de données et le support de frameworks web Python (Django, Google App Engine, Pyramid).
#     Points forts : inspection de code avancée, débogueur graphique, tests unitaires, intégration Docker, support Jupyter/Anaconda (Professional).
#     Limites : temps de chargement parfois long, consommation mémoire élevée, certaines fonctionnalités réservées à la version Professional.
#
#
#         <figure style="padding: 1em; text-align: center;">
#             <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/5/5d/JetBrains_PyCharm_Product_Logo.svg/640px-JetBrains_PyCharm_Product_Logo.svg.png" width="200" alt="Logo PyCharm">
#             <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#                 <i>Logo PyCharm – <a href="https://commons.wikimedia.org/wiki/File:JetBrains_PyCharm_Product_Logo.svg" target="_blank">Wikimedia Commons</a></i>
#             </figcaption>
#         </figure>
#         <ul style="margin-left: 1em;">
#             <li>✅ Auto-complétion très intelligente, refactoring avancé et inspection de code en temps réel.</li>
#             <li>✅ Gestion native des environnements virtuels (venv, Conda) et des packages.</li>
#             <li>⚠️ Version Professional payante pour les frameworks web et le support base de données ; la Community reste néanmoins très riche.</li>
#             <li>⚠️ Chargement parfois lent sur de gros projets.</li>
#         </ul>
#         Points forts : inspection de code avancée, débogueur graphique, tests unitaires, intégration Docker, support Jupyter/Anaconda (Professional).
# Limites : temps de chargement parfois long, consommation mémoire élevée, certaines fonctionnalités réservées à la version Professional.
#     </li>
#     <li><strong>Visual Studio Code</strong> (Microsoft) :
#     VS Code, édité par Microsoft, est un éditeur de code gratuit et open-source. Il prend en charge de nombreux langages, dont Python via une extension dédiée.
#         <figure style="padding: 1em; text-align: center;">
#             <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Visual_Studio_Code_1.35_icon.svg/1200px-Visual_Studio_Code_1.35_icon.svg.png" width="150" alt="Logo VS Code">
#             <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#                 <i>Logo Visual Studio Code – <a href="https://commons.wikimedia.org/wiki/File:Visual_Studio_Code_1.35_icon.svg" target="_blank">Wikimedia Commons</a></i>
#             </figcaption>
#         </figure>
#         <ul style="margin-left: 1em;">
#             <li>✅ Léger et très rapide au démarrage, avec terminal et Git intégrés.</li>
#             <li>✅ Énorme écosystème d’extensions (Python, Pylance, Jupyter, linters…).</li>
#             <li>⚠️ Configuration initiale des extensions Python/Jupyter peut être un peu technique.</li>
#         </ul>
#         Points forts : léger, multiplateforme, extensible (marketplace d’extensions), coloration syntaxique, IntelliSense (auto-complétion), intégration Git, terminal intégré, débogueur avancé.
# Limites : nécessite l’installation et la configuration d’extensions pour obtenir une expérience Python optimale
#     </li>
#     <li><strong>Anaconda / Jupyter Notebook</strong> :
#     Jupyter Notebook est un environnement de développement interactif accessible dans un navigateur web.
#         <figure style="padding: 1em; text-align: center;">
#             <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/38/Jupyter_logo.svg/414px-Jupyter_logo.svg.png" width="150" alt="Logo Jupyter">
#             <figcaption style="font-size: 0.9em; color: #3498db; margin-top: 0.5em;">
#                 <i>Logo Jupyter – <a href="https://commons.wikimedia.org/wiki/File:Jupyter_logo.svg" target="_blank">Wikimedia Commons</a></i>
#             </figcaption>
#         </figure>
#         <ul style="margin-left: 1em;">
#             <li>✅ Interface web interactive : code, notes et graphiques côte-à-côte.</li>
#             <li>✅ Idéal pour le data science, le machine learning et le partage de notebooks.</li>
#             <li>⚠️ Moins adapté pour des projets très structurés ou des applications complexes.</li>
#         </ul>
#         Points forts : exécution de code par cellules, support de nombreux langages (via IPython pour Python), idéal pour le data science, la visualisation et le partage de notebooks reproductibles, pas d’installation locale nécessaire si on utilise une instance distante.
# Limites : moins adapté aux projets structurés de grande envergure, absence d’outils de packaging/compilation intégrés.
#     </li>
# </ul>
#
#
# <h3 style="color:rgb(183, 232, 7); font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; border-bottom: 2px solid #3498DB; padding-bottom: 5px; margin-top: 40px;">
#     4. Fonctions clés des IDE
# </h3>
#
# Outre la coloration syntaxique et la mise en forme automatique, voici d’autres fonctionnalités majeures à rechercher dans un IDE :
#
# Auto-complétion : propose les noms de variables, fonctions, parenthèses, etc., pour accélérer la saisie et réduire les erreurs.
#
# Débogage : permet d’exécuter le code pas à pas, de poser des points d’arrêt, d’inspecter les variables et la pile d’appels pour localiser rapidement les bugs.
#
# Génération d’exécutables : compile et package le code en fichiers exécutables autonomes.
#
# Compilateur/Interpréteur intégré : compile ou interprète le code sans quitter l’IDE, pour un cycle « éditer–tester » fluide.
#
# Intégration du contrôle de version : interfaces graphiques pour Git, Mercurial, SVN, etc., permettant de gérer commits, branches et fusions directement dans l’IDE.

# %% [markdown]
# <div id="section2"></div>
# <a href="#toc" style="background-color: #E1B12D; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 50px;">Retour en haut</a><a id="toc"></a>
#
# <h2 style="color: #3498DB; font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; border-bottom: 2px solid #3498DB; padding-bottom: 5px; margin-top: 40px;">
#     II. Installation de Python 📥
# </h2>
# <p style="font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.1em; line-height: 1.6em;">
#     Allons chercher Python directement à la source : <a href="https://www.python.org/downloads/" target="_blank" style="color: #3498DB; text-decoration: none;"><strong>python.org/downloads</strong></a>.
#     <br/><br/>
#     <strong>Étapes clés</strong> :
# </p>
#
# <ol style="font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.1em; margin-left: 1.5em; line-height: 1.6em;">
#     <li><strong>Télécharger l’installeur</strong> pour votre OS (Windows, macOS, Linux).</li>
#     <li><strong>Exécuter l’installeur</strong> :
#         <ul style="margin-left: 1em;">
#             <li>✔️ Cochez « Add Python to PATH » sur Windows.</li>
#             <li>✔️ Sur macOS, glissez‑déposez dans Applications ou utilisez Homebrew (<code>brew install python</code>).</li>
#             <li>✔️ Sous Linux, privilégiez le gestionnaire de paquets (<code>sudo apt install python3</code>).</li>
#         </ul>
#     </li>
#     <li><strong>Vérifier l’installation</strong> :
#         <pre style="background: #f4f4f4; padding: 10px; border-radius: 5px; overflow-x: auto; font-family: Consolas, monospace; font-size: 0.95em;">
# $ python --version
# Python 3.x.x
#         </pre>
#     </li>
# </ol>

# %% [markdown]
# <div id="section3"></div>
# <a href="#toc" style="background-color: #E1B12D; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 50px;">Retour en haut</a><a id="toc"></a>
#
# <h2 style="color: #3498DB; font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; border-bottom: 2px solid #3498DB; padding-bottom: 5px; margin-top: 40px;">
#     III. Environnements virtuels 🐍
# </h2>
# <p style="font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.1em; line-height: 1.6em;">
#     Pourquoi un environnement virtuel ? Pour isoler les dépendances de chaque projet et éviter les conflits de versions.
#     <br/><br/>
#     <strong>Créer et activer un venv</strong> (module standard) :
# </p>
# <pre style="background: #f4f4f4; padding: 10px; border-radius: 5px; overflow-x: auto; font-family: Consolas, monospace; font-size: 0.95em;">
# $ python -m venv mon_env
# $ # Windows
# $ mon_env\Scripts\activate
# $ # macOS / Linux
# $ source mon_env/bin/activate
# </pre>
# <p style="font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.1em; line-height: 1.6em;">
#     Pour quitter l’environnement :
#     <code>deactivate</code>
#     <br/><br/>
#     <strong>Alternative Conda</strong> (Anaconda/Miniconda) :
#     <pre style="background: #f4f4f4; padding: 10px; border-radius: 5px; overflow-x: auto; font-family: Consolas, monospace; font-size: 0.95em;">
# $ conda create -n mon_env_conda python=3.x
# $ conda activate mon_env_conda
# $ conda deactivate
#     </pre>
# </p>

# %% [markdown]
# <div id="section4"></div>
# <a href="#toc" style="background-color: #E1B12D; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 50px;">Retour en haut</a><a id="toc"></a>
#
# <h2 style="color: #3498DB; font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; border-bottom: 2px solid #3498DB; padding-bottom: 5px; margin-top: 40px;">
#     IV. Package Managers 📦
# </h2>
# <p style="font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.1em; line-height: 1.6em;">
#     Gérer vos bibliothèques, c’est comme ranger vos outils : on veut un système clair et fiable.
#     <br/><br/>
#     <strong>pip</strong> (standard) :
# </p>
# <ul style="font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.1em; margin-left: 1.5em; line-height: 1.6em;">
#     <li>Installer : <code>pip install nom_du_package</code></li>
#     <li>Mettre à jour : <code>pip install --upgrade nom_du_package</code></li>
#     <li>Désinstaller : <code>pip uninstall nom_du_package</code></li>
#     <li>Lister : <code>pip list</code></li>
#     <li>Exporter : <code>pip freeze &gt; requirements.txt</code></li>
# </ul>
# <p style="font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.1em; line-height: 1.6em;">
#     <strong>Poetry</strong> (gestion avancée) :
#     <ul style="margin-left: 1.5em;">
#         <li>✔️ Fichier <code>pyproject.toml</code> pour config unifiée.</li>
#         <li>✔️ Isolation et publication simplifiée.</li>
#     </ul>
#     <strong>Conda</strong> (via Anaconda) :
#     <ul style="margin-left: 1.5em;">
#         <li>✔️ Environnements + packages scientifiques pré‑compilés.</li>
#         <li>⚠️ Lourd à installer si on n’a pas besoin de tout l’écosystème.</li>
#     </ul>
# </p>

# %% [markdown]
# <div id="section6"></div>
#
# <a href="#toc" style="background-color: #E1B12D; color: #ffffff; padding: 7px 15px; text-decoration: none; border-radius: 50px;">Retour en haut</a><a id="toc"></a>
#
# <h2 style="color: #3498DB; font-family: 'Segoe UI', Arial, sans-serif; font-size: 1.8em; border-bottom: 2px solid #3498DB; padding-bottom: 5px; margin-top: 40px;">
#     VI. 📚 Ressources complémentaires
# </h2>
#
# <div style="display: flex; align-items: flex-start;">
#   <div style="flex: 1; padding: 1em;">
#     <p>
#         - 📖 <a href="https://codeur-pro.fr/comment-creer-un-programme/" target="_blank">Article de Blog - Comment créer un programme?</a> - une bonne illustration de la différence entre language compilé et interprété.<br/>
#         - 📖 <a href="https://laconsole.dev/blog/differences-langage-compile-interprete" target="_blank">Article de Blog - Différences entre Langage Interprété et Compilé</a>
#     </p>
#     <!-- Vous pouvez continuer votre texte ici -->
#   </div>
# </div>
